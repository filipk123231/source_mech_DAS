# %%
import get_source_mech

# %%
import pandas as pd

# %%
eqdata = pd.read_csv('eqdata2.csv')

# %%
eqlon = eqdata.longitude[0]
eqlat = eqdata.latitude[0]
eqdepth = eqdata['depth[km]'][0]

# %%
print(eqlon)
print(eqlat)
print(eqdepth)
# Out:
# 17.745
# 42.722
# 9.5

# %%
get_source_mech.get_source_mech(files=['../zar_meh/SR_DS100Hz_2025-12-17_22-07-29_UTC.h5'], dev='febus',
 eqlon=eqlon, eqlat=eqlat, eqdepth=eqdepth, output_folder='./output/', pathToEqNet='/home/a/EQNet/predict.py', ignorePicksStartSec=5, ignorePicksEndSec=10, topN_median=30)
# Out:
# /home/a/miniforge3/envs/sci/lib/python3.11/site-packages/xdas/io/febus.py:61: UserWarning: No overlap specified, Xdas will try its best to find the correct trimming
#   warnings.warn(
# /home/a/miniforge3/envs/sci/lib/python3.11/site-packages/xdas/io/febus.py:75: UserWarning: No offset specified, Xdas will try its best to place the timestamps
#   warnings.warn(
# python /home/a/EQNet/predict.py --model phasenet_das --data_list=/mnt/e/source_mech_DAS/files.txt  --data_path /mnt/e/source_mech_DAS/das_data_converted --result_path /mnt/e/source_mech_DAS/results --format=h5  --batch_size 1 --workers 0 --device cpu
# Not using distributed mode
# Namespace(model='phasenet_das', resume='', backbone='unet', phases=['P', 'S'], device='cpu', workers=0, batch_size=1, use_deterministic_algorithms=False, amp=False, world_size=1, dist_url='env://', data_path='/mnt/e/source_mech_DAS/das_data_converted', data_list='/mnt/e/source_mech_DAS/files.txt', hdf5_file=None, prefix='', format='h5', dataset='das', result_path='/mnt/e/source_mech_DAS/results', plot_figure=False, min_prob=0.3, add_polarity=False, add_event=False, sampling_rate=100.0, highpass_filter=0.0, response_path=None, response_xml=None, subdir_level=0, cut_patch=False, nt=20480, nx=5120, resample_time=False, resample_space=False, system=None, location=None, skip_existing=False, distributed=False)
# Total samples: 1 files
# Downloading: "https://github.com/AI4EPS/models/releases/download/PhaseNet-DAS-v1/PhaseNet-DAS-v1.pth" to ./model_phasenet_das/PhaseNet-DAS-v1.pth
# 100%|██████████| 122M/122M [00:11<00:00, 11.5MB/s]
# Predicting: 100%|██████████| 1/1 [00:09<00:00,  9.38s/it]
# Calculating theoretical arrivals.........
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done 256 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=-1)]: Done 418 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=-1)]: Done 616 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=-1)]: Done 850 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-1)]: Done 1120 tasks      | elapsed:   14.4s
# [Parallel(n_jobs=-1)]: Done 1426 tasks      | elapsed:   17.4s
# [Parallel(n_jobs=-1)]: Done 1768 tasks      | elapsed:   20.7s
# [Parallel(n_jobs=-1)]: Done 2146 tasks      | elapsed:   24.4s
# [Parallel(n_jobs=-1)]: Done 2560 tasks      | elapsed:   28.4s
# [Parallel(n_jobs=-1)]: Done 3010 tasks      | elapsed:   33.0s
# [Parallel(n_jobs=-1)]: Done 3496 tasks      | elapsed:   38.0s
# Done!
# [Parallel(n_jobs=-1)]: Done 4000 out of 4000 | elapsed:   42.9s finished
# /home/a/miniforge3/envs/sci/lib/python3.11/site-packages/xdas/io/febus.py:61: UserWarning: No overlap specified, Xdas will try its best to find the correct trimming
#   warnings.warn(
# /home/a/miniforge3/envs/sci/lib/python3.11/site-packages/xdas/io/febus.py:75: UserWarning: No offset specified, Xdas will try its best to place the timestamps
#   warnings.warn(
# Performing grid search.......
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 237 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done 3088 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done 37392 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=-1)]: Done 88080 tasks      | elapsed:    8.4s
# [Parallel(n_jobs=-1)]: Done 147984 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-1)]: Done 217104 tasks      | elapsed:   15.5s
# [Parallel(n_jobs=-1)]: Done 295440 tasks      | elapsed:   19.8s
# [Parallel(n_jobs=-1)]: Done 382992 tasks      | elapsed:   24.6s
# [Parallel(n_jobs=-1)]: Done 479760 tasks      | elapsed:   29.9s
# [Parallel(n_jobs=-1)]: Done 585744 tasks      | elapsed:   35.7s
# [Parallel(n_jobs=-1)]: Done 700944 tasks      | elapsed:   42.0s
# [Parallel(n_jobs=-1)]: Done 825360 tasks      | elapsed:   48.8s
# [Parallel(n_jobs=-1)]: Done 958992 tasks      | elapsed:   56.1s
# [Parallel(n_jobs=-1)]: Done 1101840 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 1253904 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 1415184 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 1585680 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 1765392 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 1954320 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 2152464 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 2359824 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 2576400 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 2802192 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 3037200 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 3281424 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 3534864 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 3797520 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 4069392 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 4350480 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=-1)]: Done 4640784 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 4940304 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 5249040 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 5566992 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done 5894160 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done 5929560 out of 5929560 | elapsed:  5.6min finished
# Beachball min
# Beachball top 30 median
# phi delta lambda min
# 256 27 62
# 106.8267012229202 66.36868448265763 103.45280298381785
# phi delta lambda top 30 median
# 243.5 23.5 55.5
# 100.34933557235769 70.81499077442417 103.83548974081813
